# %%
import pandas as pd

# %%
#df = pd.read_csv('./ec2/data/v0.csv', index_col=0)
df = pd.read_csv('v0.csv', index_col=0)

# %%
df.to_csv('./ec2/data/v0.csv', mode='a', header=False)

# %%
df.shape
# Out:
# (32469, 41)

# %%
df.action.describe()
# Out:
# count    32469.000000
# mean         1.478395
# std          0.801857
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000
# Name: action, dtype: float64

# %%
df2 = pd.read_csv('./ec2/data/v1.csv', index_col=0)

# %%
df2.to_csv('./ec2/data/v1.csv', mode='a', header=False)

# %%
df2.shape
# Out:
# (23, 41)

# %%
df2
# Out:
#     action  action_last_0  action_last_1  action_last_2  action_last_3  \
# 0        1       1.000000       1.000000       0.000000       0.000000
# 1        3       1.000000       1.000000       0.333333       0.000000
# 2        2       1.000000       1.000000       0.333333       1.000000
# 3        3       1.000000       1.000000       0.333333       1.000000
# 4        1       1.000000       0.333333       1.000000       0.666667
# 5        2       0.333333       0.333333       1.000000       0.666667
# 6        3       0.333333       0.666667       0.333333       0.666667
# 7        2       0.333333       0.666667       0.333333       1.000000
# 8        3       0.333333       0.666667       0.333333       1.000000
# 9        2       0.333333       0.333333       1.000000       0.666667
# 10       2       0.333333       0.666667       0.333333       0.666667
# 11       1       0.333333       0.666667       0.333333       0.666667
# ...
